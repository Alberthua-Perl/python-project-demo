# %%
from matplotlib import pyplot as plt

# %%
instructors = ['John','Chris','Harry','Robert','Abhay']

# %%
nps = [80,89,92,88,95]

# %%
plt.bar(instructors,nps,color='Green')
# Out:
# <BarContainer object of 5 artists>

# %% [raw]
# plt.show()
