# %% [markdown]
# # Lesson 20. 控制语句（二）：循环语句  <span style="color:blue">[DONE]</span>

# %% [markdown]
# &emsp;&emsp;控制语句的第二部分，我们来讨论关于循环语句。和控制语句不同，循环语句侧重于对一个容器内的每个元素依次进行某种处理，从而达到批量处理的逻辑。可以说，**循环的本质就是进行批量处理**，而之前介绍的 “容器” 的概念，则是支持批量处理最佳功能，当然，Python 中之所以要创立容器，很重要的一方面原因也是希望能够借助容器的概念实现批量处理，从而提高代码表意效率。当然，这里所谓的批量处理不是真正意义上的一次性把一个容器内的所有元素 “批量” 的进行处理，而是将一个容器中的各元素依次执行某相同代码、再把这些结果返回并存储到某容器中，从而实现 “批量” 处理的效果。

# %% [markdown]
# &emsp;&emsp;我们先看下，如果不用 for 循环，要对一个包含 1、2、3 三个数值的列表内的元素分别 +1，要怎么操作。

# %%
l = [1, 2, 3]

# %%
l[0] += 1
l[1] += 1
l[2] += 1
# 列表是可变类型对象，可以利用索引直接修改内部元素。

# %%
l
# Out:
# [2, 3, 4]

# %% [markdown]
# &emsp;&emsp;但很明显，代码显得过于冗杂，且可拓展性不强。此时可考虑使用 for 循环来完成上述逻辑。

# %%
l = [1, 2, 3]

for i in range(len(l)):
    l[i] += 1

# %%
l
# Out:
# [2, 3, 4]

# %%
range(len(l))
# Out:
# range(0, 3)

# %%
l = [1, 2, 3, 5, 6, 7]

for i in range(len(l)):
    l[i] += 1

l
# Out:
# [2, 3, 4, 6, 7, 8]

# %% [markdown]
# ## 1. for 循环基本结构

# %% [markdown]
# &emsp;&emsp;for 循环是最常见的循环结构，其基本语法结构为：
#
# ```python
# for <临时变量> in <容器>:
#     <表达式>
# ```
#
# &emsp;&emsp;其中 for 是循环体的提示符，在之前的例子中，i 就是 **临时变量**，range(len(l)) 是容器，l[i] += 1 是包含临时变量的表达式，在实际的执行过程中，临时变量 i 依次取得 range(len(l)) 容器中的每一个值（即 0、1、2），并且每取得一个值就进行一次表达式的运算，最终通过一次次的循环计算，完成列表 l 中每个值 +1 的运算。

# %%
l = [1, 2, 3]

for i in range(len(l)):
    l[i] += 1
print(l)
# Out:
# [2, 3, 4]

# %% [markdown]
# **Points:**
#
# - range 类型本身也是可迭代对象（range 对象），只要是可迭代对象，就能够用 for 循环遍历；
# - 同样 dict_keys 对象与 dict_values 对象都是可迭代对象；
# - i 虽然名叫临时变量，但当循环结束时，i 会取得最后一次循环时的取值。

# %%
i
# Out:
# 2

# %%
l = [1, 2, 3]
i = 10

for i in l:
    print(i)
print(i)
# Out:
# 1
# 2
# 3
# 3

# %% [markdown]
# &emsp;&emsp;因此，在实际使用循环过程中，要谨慎的选取临时变量名，尽量避免和已有变量重名，以避免造成不必要的麻烦。

# %% [markdown]
# ## 2. 可迭代对象

# %% [markdown]
# &emsp;&emsp;之前在介绍基本数据类型时，曾介绍过容器属性可从可变、有序两个方面来考察。其中：
#
# - **数值型对象**（整型数对象与浮点数对象）由于不可索引，因此不是容器；

# %%
1[0]
# Out:
# <>:1: SyntaxWarning: 'int' object is not subscriptable; perhaps you missed a comma?
# <>:1: SyntaxWarning: 'int' object is not subscriptable; perhaps you missed a comma?
# /tmp/ipykernel_16984/1270219447.py:1: SyntaxWarning: 'int' object is not subscriptable; perhaps you missed a comma?
#   1[0]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 1[0]
#
# TypeError: 'int' object is not subscriptable

# %% [markdown]
# - **字符串型对象** 可以利用数值进行索引，但不能利用索引进行修改，因此是 **不可变的有序对象**；

# %%
'Hello'[1]
# Out:
# 'e'

# %%
'Hello'[1] = 'a'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 'Hello'[1] = 'a'
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# - **列表型对象** 可以利用数值进行索引，并且可以利用索引进行修改，因此是 **可变的有序对象**；

# %%
l = [1, 2, 3]
l[1]
# Out:
# 2

# %%
l[1] = 0

# %%
l
# Out:
# [1, 0, 3]

# %% [markdown]
# - **元组型对象** 可以利用数值进行索引，但不能利用索引进行修改，因此和字符串对象类似，是 **不可变的有序对象**；

# %%
t = tuple(range(5))
t
# Out:
# (0, 1, 2, 3, 4)

# %%
t[1]
# Out:
# 1

# %%
t[1] = 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 t[1] = 2
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# - **字典型对象** 不能利用数值进行索引，只能利用 key 来进行索引，而 key 的索引结果是可以修改的，因此字典对象是 **可变的无序对象**；

# %%
d = dict([('A', 1), ('B', 2)])
d
# Out:
# {'A': 1, 'B': 2}

# %%
d[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 d[1]
#
# KeyError: 1

# %%
d['A']
# Out:
# 1

# %%
d['A'] = 3

# %%
d
# Out:
# {'A': 3, 'B': 2}

# %% [markdown]
# - **集合型对象** 不能利用数值进行索引，但可以修改，因此集合类型对象和字典一样是 **可变的无序对象**；

# %%
s = set([1, 2, 3])

# %%
s
# Out:
# {1, 2, 3}

# %%
s.remove(1)

# %%
s
# Out:
# {2, 3}

# %%
{1, 2, (1, 2), {1, 2}}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 {1, 2, (1, 2), {1, 2}}
#
# TypeError: unhashable type: 'set'

# %% [markdown]
# - **冻集合** 是在集合的基础之上进一步要求集合本身不可变，因此冻集合是 **不可变的无序对象**。

# %%
sf = frozenset([1, 2, 3])
sf
# Out:
# frozenset({1, 2, 3})

# %%
sf.remove(1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 sf.remove(1)
#
# AttributeError: 'frozenset' object has no attribute 'remove'

# %%
{1, 2, (1, 2), frozenset([1, 2])}
# Out:
# {(1, 2), 1, 2, frozenset({1, 2})}

# %% [markdown]
# **Points:**
#
# - 在这所有的对象类型中，**除了 int 之外，都是可迭代类型对象**，都可以作为 for...in... 的循环对象；
# - 根据有序、无序的不同，临时变量取值效果会有所不同；
# - 若要利用循环对对象本身进行修改（类似上面把列表中的每个元素+1），仍然只能修改可变类型对象;
# - 之前介绍的原容器类型对象（range、dict_keys、dict_values、dict_items 等）都是可迭代类型对象。

# %% [markdown]
# ## 3. 有序变量的循环

# %% [markdown]
# ### 3.1 有序可变类型对象循环

# %% [markdown]
# &emsp;&emsp;截止目前，我们接触到的 **有序可变类型对象只有列表**，列表可以在 for...in... 结构中充当可迭代类型对象，同时也可以作为 for 循环修改对象。

# %%
l = [1, 0, 3]
l
# Out:
# [1, 0, 3]

# %%
for i in l:    # 充当容器，在 for...in... 结构中。
    print(i)
# Out:
# 1
# 0
# 3

# %%
for i in range(len(l)):
    l[i] += 1    # 修改 l 中元素

# %%
l
# Out:
# [1, 0, 3]

# %% [markdown]
# ### 3.2 有序不可变类型对象的循环

# %% [markdown]
# &emsp;&emsp;截止目前，**有序不可变类型对象有字符串对象和元组对象两种**，对于有序不可变类型对象，由于本身是可迭代类型对象，因此可以出现在 for...in... 结构中，但由于是不可变的，因此不能通过循环对其进行修改。

# %%
s = 'Hello'
s
# Out:
# 'Hello'

# %%
for i in s:
    print(i)
# Out:
# H
# e
# l
# l
# o

# %%
for i in range(len(s)):
    s[i] = 'a'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 for i in range(len(s)):
# ----> 2     s[i] = 'a'
#
# TypeError: 'str' object does not support item assignment

# %%
t = tuple([1, 0, 3])
t
# Out:
# (1, 0, 3)

# %%
for i in t:        # 充当容器，在 for...in... 结构中。
    print(i)
# Out:
# 1
# 0
# 3

# %%
for i in range(len(t)):        
    t[i] += 1                   # 修改 l 中元素
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 for i in range(len(t)):
# ----> 2     t[i] += 1                   # 修改 l 中元素
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ## 4. 无序变量的循环

# %% [markdown]
# &emsp;&emsp;**无序变量又分为无序可变变量（如字典、集合）与无序不可变变量（如冻集合）**，同理，无序可变变量能够通过循环修改，不可变变量不能利用循环进行修改，同时需要注意的是无序变量在 for...in... 结构中遍历顺序的问题。

# %%
d = dict([('B', [1, 2, 3]), ('A', 1)])
d
# Out:
# {'B': [1, 2, 3], 'A': 1}

# %%
for i in d:  # 对字典对象的迭代就是对 key 的迭代
    print(i)
# Out:
# B
# A

# %%
# 示例：根据字典对象的 key 索引对应的 value（Alberthua 新增）
d1 = dict([('a', 5), ('b', 7), ('c', 9)])

for i in d1.keys():
    print(f"Key {i} -> Value {d1[i]}")
# Out:
# Key a -> Value 5
# Key b -> Value 7
# Key c -> Value 9

# %% [markdown]
# &emsp;&emsp;据此可知，对于无序变量的循环，本质上是根据显示顺序进行遍历。同时，若是针对字典进行循环，本质上是对字典的 keys 进行循环。

# %%
s = set([1, 2, 3, (1, 2)])
s
# Out:
# {(1, 2), 1, 2, 3}

# %%
for i in s:
    print(i)
# Out:
# (1, 2)
# 1
# 2
# 3

# %%
sf = frozenset(s)

# %%
for i in sf:
    print(i)
# Out:
# (1, 2)
# 1
# 2
# 3

# %% [markdown]
# ## 5. 循环的嵌套

# %% [markdown]
# &emsp;&emsp;循环也可以进行嵌套，以实现更加丰富的逻辑功能。例如：

# %%
d = dict([('B', [1, 2, 3]), ('A', 1)])
d
# Out:
# {'B': [1, 2, 3], 'A': 1}

# %%
type(d['B']) == list
# Out:
# True

# %%
for i in d:
    #print(i)
    if type(d[i]) == list:
        for j in range(len(d[i])):
            d[i][j] += 1
    print(d[i])
# Out:
# [3, 4, 5]
# 1
